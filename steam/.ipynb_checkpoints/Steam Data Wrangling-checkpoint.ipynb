# %%
import pandas as pd
from fastai.vision.all import *

import requests # api and image downloads
import shutil # save images to disk

# %%
def all(page=0):
    url = f"https://steamspy.com/api.php?request=all&page={page}"
    r = requests.get(url)
    return pd.read_json(r.text).T

# %%
def download_header(appid):
    filename = f"headers/{appid}.jpg"
    # Open the url image, set stream to True, this will return the stream content.
    r = requests.get(f"https://cdn.cloudflare.steamstatic.com/steam/apps/{appid}/header.jpg", stream = True)

    # Check if the image was retrieved successfully
    if r.status_code == 200:
        # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
        r.raw.decode_content = True
    
        # Open a local file with wb ( write binary ) permission.
        with open(filename,'wb') as f:
            shutil.copyfileobj(r.raw, f)
        
        print('Image sucessfully Downloaded: ',filename)
    else:
        print('Image Couldn\'t be retreived', appid)

# %%
df = all(0)
for page in range(1, 60):
    p = all(page)
    df = pd.concat([df, p])

# %%
df["reviews"] = df["negative"] + df["positive"]

# %%
df.to_pickle("steam.pkl")

# %%
df = pd.read_pickle("steam.pkl")

# %%
download_images("headers", urls=["https://cdn.cloudflare.steamstatic.com/steam/apps/730/header.jpg"])

# %%
df
# Out:
#            appid                               name          developer  \
# 10            10                     Counter-Strike              Valve
# 20            20              Team Fortress Classic              Valve
# 30            30                      Day of Defeat              Valve
# 40            40                 Deathmatch Classic              Valve
# 50            50          Half-Life: Opposing Force   Gearbox Software
# ...          ...                                ...                ...
# 2218660  2218660             Onefold Taxi Simulator         DayalGames
# 2220350  2220350  I commissioned some bees (advent)     Follow The Fun
# 2221710  2221710                       Ultra Rhythm        Music Games
# 2222200  2222200                       Springblades  Sokpop Collective
# 2223920  2223920                        GLOBE DRONE      Archor Wright
#
#                  publisher score_rank positive negative userscore  \
# 10                   Valve              206528     5274         0
# 20                   Valve                5917      935         0
# 30                   Valve                5326      582         0
# 40                   Valve                1989      447         0
# 50                   Valve               15121      769         0
# ...                    ...        ...      ...      ...       ...
# 2218660         DayalGames                   1        0         0
# 2220350     Follow The Fun                   1        0         0
# 2221710        Music Games                   1        4         0
# 2222200  Sokpop Collective                   0        0         0
# 2223920       Archor Games                   2        0         0
#
#                            owners average_forever average_2weeks  \
# 10       10,000,000 .. 20,000,000            9854             32
# 20         1,000,000 .. 2,000,000            1011              0
# 30        5,000,000 .. 10,000,000            1145              6
# 40        5,000,000 .. 10,000,000            1631              0
# 50        5,000,000 .. 10,000,000            1040              8
# ...                           ...             ...            ...
# 2218660               0 .. 20,000               0              0
# 2220350               0 .. 20,000               0              0
# 2221710               0 .. 20,000               0              0
# 2222200               0 .. 20,000               0              0
# 2223920               0 .. 20,000               0              0
#
#         median_forever median_2weeks price initialprice discount    ccu  \
# 10                 205            44   999          999        0  14756
# 20                  15             0   499          499        0     95
# 30                  30             6   499          499        0    132
# 40                  11             0   499          499        0     12
# 50                 186             8   499          499        0    185
# ...                ...           ...   ...          ...      ...    ...
# 2218660              0             0  1499         1499        0      0
# 2220350              0             0   424          499       15      3
# 2221710              0             0   139          199       30      1
# 2222200              0             0   799          799        0     29
# 2223920              0             0    69           99       30      0
#
#         reviews
# 10       211802
# 20         6852
# 30         5908
# 40         2436
# 50        15890
# ...         ...
# 2218660       1
# 2220350       1
# 2221710       5
# 2222200       0
# 2223920       2
#
# [59042 rows x 18 columns]

# %%
df["header"] = df.apply(lambda x: , axis=1)

# %%
df
# Out:
#            appid                               name          developer  \
# 10            10                     Counter-Strike              Valve
# 20            20              Team Fortress Classic              Valve
# 30            30                      Day of Defeat              Valve
# 40            40                 Deathmatch Classic              Valve
# 50            50          Half-Life: Opposing Force   Gearbox Software
# ...          ...                                ...                ...
# 2218660  2218660             Onefold Taxi Simulator         DayalGames
# 2220350  2220350  I commissioned some bees (advent)     Follow The Fun
# 2221710  2221710                       Ultra Rhythm        Music Games
# 2222200  2222200                       Springblades  Sokpop Collective
# 2223920  2223920                        GLOBE DRONE      Archor Wright
#
#                  publisher score_rank positive negative userscore  \
# 10                   Valve              206528     5274         0
# 20                   Valve                5917      935         0
# 30                   Valve                5326      582         0
# 40                   Valve                1989      447         0
# 50                   Valve               15121      769         0
# ...                    ...        ...      ...      ...       ...
# 2218660         DayalGames                   1        0         0
# 2220350     Follow The Fun                   1        0         0
# 2221710        Music Games                   1        4         0
# 2222200  Sokpop Collective                   0        0         0
# 2223920       Archor Games                   2        0         0
#
#                            owners average_forever average_2weeks  \
# 10       10,000,000 .. 20,000,000            9854             32
# 20         1,000,000 .. 2,000,000            1011              0
# 30        5,000,000 .. 10,000,000            1145              6
# 40        5,000,000 .. 10,000,000            1631              0
# 50        5,000,000 .. 10,000,000            1040              8
# ...                           ...             ...            ...
# 2218660               0 .. 20,000               0              0
# 2220350               0 .. 20,000               0              0
# 2221710               0 .. 20,000               0              0
# 2222200               0 .. 20,000               0              0
# 2223920               0 .. 20,000               0              0
#
#         median_forever median_2weeks price initialprice discount    ccu  \
# 10                 205            44   999          999        0  14756
# 20                  15             0   499          499        0     95
# 30                  30             6   499          499        0    132
# 40                  11             0   499          499        0     12
# 50                 186             8   499          499        0    185
# ...                ...           ...   ...          ...      ...    ...
# 2218660              0             0  1499         1499        0      0
# 2220350              0             0   424          499       15      3
# 2221710              0             0   139          199       30      1
# 2222200              0             0   799          799        0     29
# 2223920              0             0    69           99       30      0
#
#         reviews  \
# 10       211802
# 20         6852
# 30         5908
# 40         2436
# 50        15890
# ...         ...
# 2218660       1
# 2220350       1
# 2221710       5
# 2222200       0
# 2223920       2
#
#                                                                        header
# 10            https://cdn.cloudflare.steamstatic.com/steam/apps/10/header.jpg
# 20            https://cdn.cloudflare.steamstatic.com/steam/apps/20/header.jpg
# 30            https://cdn.cloudflare.steamstatic.com/steam/apps/30/header.jpg
# 40            https://cdn.cloudflare.steamstatic.com/steam/apps/40/header.jpg
# 50            https://cdn.cloudflare.steamstatic.com/steam/apps/50/header.jpg
# ...                                                                       ...
# 2218660  https://cdn.cloudflare.steamstatic.com/steam/apps/2218660/header.jpg
# 2220350  https://cdn.cloudflare.steamstatic.com/steam/apps/2220350/header.jpg
# 2221710  https://cdn.cloudflare.steamstatic.com/steam/apps/2221710/header.jpg
# 2222200  https://cdn.cloudflare.steamstatic.com/steam/apps/2222200/header.jpg
# 2223920  https://cdn.cloudflare.steamstatic.com/steam/apps/2223920/header.jpg
#
# [59042 rows x 19 columns]

# %%
urls = df["header"]

# %%
for appid in df["appid"]:
    download_header(appid)
# Out:
# Image sucessfully Downloaded:  headers/10.jpg
# Image sucessfully Downloaded:  headers/20.jpg
# Image sucessfully Downloaded:  headers/30.jpg
# Image sucessfully Downloaded:  headers/40.jpg
# Image sucessfully Downloaded:  headers/50.jpg
# Image sucessfully Downloaded:  headers/60.jpg
# Image sucessfully Downloaded:  headers/70.jpg
# Image sucessfully Downloaded:  headers/80.jpg
# Image sucessfully Downloaded:  headers/130.jpg
# Image sucessfully Downloaded:  headers/220.jpg
# Image sucessfully Downloaded:  headers/240.jpg
# Image sucessfully Downloaded:  headers/280.jpg
# Image sucessfully Downloaded:  headers/300.jpg
# Image sucessfully Downloaded:  headers/320.jpg
# Image sucessfully Downloaded:  headers/340.jpg
# Image sucessfully Downloaded:  headers/360.jpg
# Image sucessfully Downloaded:  headers/380.jpg
# Image sucessfully Downloaded:  headers/400.jpg
# Image sucessfully Downloaded:  headers/420.jpg
# Image sucessfully Downloaded:  headers/440.jpg
# Image sucessfully Downloaded:  headers/500.jpg
# Image sucessfully Downloaded:  headers/550.jpg
# Image sucessfully Downloaded:  headers/570.jpg
# Image sucessfully Downloaded:  headers/620.jpg
# Image sucessfully Downloaded:  headers/630.jpg
# Image sucessfully Downloaded:  headers/730.jpg
# Image Couldn't be retreived
# Image sucessfully Downloaded:  headers/1002.jpg
# Image sucessfully Downloaded:  headers/1200.jpg
# Image sucessfully Downloaded:  headers/1250.jpg
# Image sucessfully Downloaded:  headers/1300.jpg
# Image sucessfully Downloaded:  headers/1309.jpg
# Image sucessfully Downloaded:  headers/1313.jpg
# Image sucessfully Downloaded:  headers/1500.jpg
# Image sucessfully Downloaded:  headers/1500.jpg
# Image sucessfully Downloaded:  headers/1510.jpg
# Image sucessfully Downloaded:  headers/1520.jpg
# Image sucessfully Downloaded:  headers/1530.jpg
# Image sucessfully Downloaded:  headers/1600.jpg
# Image sucessfully Downloaded:  headers/1610.jpg
# Image sucessfully Downloaded:  headers/1630.jpg
# Image sucessfully Downloaded:  headers/1640.jpg
# Image sucessfully Downloaded:  headers/1670.jpg
# Image sucessfully Downloaded:  headers/1690.jpg
# Image sucessfully Downloaded:  headers/1700.jpg
# Image sucessfully Downloaded:  headers/1840.jpg
